# %%
#Importing Packages
import os
import sys
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

pd.options.display.max_rows = 500
pd.options.display.max_columns = 100

import warnings
warnings.filterwarnings("ignore") 

from datetime import datetime
from IPython.display import display, Markdown

# %%
#reading the datasets
seattle_streets = pd.read_csv('../data_sources/Seattle_Streets.csv')
collisions = pd.read_csv('../data_sources/Collisions.csv')

# %%
seattle_streets.head()
# Out:
#    OBJECTID  ARTCLASS  COMPKEY  UNITID  UNITID2  UNITIDSORT  \
# 0         1       2.0     1006    10.0    120.0    100120.0
# 1         2       2.0     1009    10.0    150.0    100150.0
# 2         3       0.0     1032    15.0     80.0    150080.0
# 3         4       0.0     1051    15.0    230.0    150230.0
# 4         5       0.0     1060    15.0    282.0    150282.0
#
#                                          UNITDESC STNAME_ORD           XSTRLO  \
# 0     1ST AVE BETWEEN SENECA ST AND UNIVERSITY ST    1ST AVE        SENECA ST
# 1             1ST AVE BETWEEN PIKE ST AND PINE ST    1ST AVE          PIKE ST
# 2  1ST AVE N BETWEEN VALLEY UPPER ST AND ALOHA ST  1ST AVE N  VALLEY UPPER ST
# 3       1ST AVE N BETWEEN LYNN ST AND MCGRAW S ST  1ST AVE N          LYNN ST
# 4   1ST AVE N BETWEEN FULTON S ST AND FULTON N ST  1ST AVE N      FULTON S ST
#
#           XSTRHI     ARTDESCRIPT OWNER STATUS  BLOCKNBR  SPEEDLIMIT SEGDIR  \
# 0  UNIVERSITY ST  Minor Arterial        INSVC    1200.0        25.0     NW
# 1        PINE ST  Minor Arterial        INSVC    1500.0        25.0     NW
# 2       ALOHA ST  Not Designated        INSVC     800.0        20.0      N
# 3    MCGRAW S ST  Not Designated        INSVC    2200.0        20.0      N
# 4    FULTON N ST  Not Designated        INSVC    2800.0        20.0      N
#
#   ONEWAY ONEWAYDIR FLOW  SEGLENGTH  SURFACEWIDTH SURFACETYPE_1 SURFACETYPE_2  \
# 0      N                     306.0          48.0           PCC        AC/PCC
# 1      N                     426.0         104.0        AC/PCC           PCC
# 2      N                     297.0           0.0           PCC           NaN
# 3      N                     175.0          25.0            AC           NaN
# 4      N                      73.0           0.0           PCC           NaN
#
#                           INTRLO DIRLO  INTKEYLO                     INTRHI  \
# 0          1ST AVE AND SENECA ST    NW   29611.0  1ST AVE AND UNIVERSITY ST
# 1            1ST AVE AND PIKE ST    NW   29593.0        1ST AVE AND PINE ST
# 2  1ST AVE N AND VALLEY UPPER ST     N   28897.0     1ST AVE N AND ALOHA ST
# 3          1ST AVE N AND LYNN ST     N   28113.0  1ST AVE N AND MCGRAW S ST
# 4      1ST AVE N AND FULTON S ST     N   28051.0  1ST AVE N AND FULTON N ST
#
#   DIRHI NATIONHWYSYS                 STREETTYPE  PVMTCONDINDX1  PVMTCONDINDX2  \
# 0    SE            N      Downtown Neighborhood           87.0           62.0
# 1    SE            N      Downtown Neighborhood           57.0           58.0
# 2     S            N  Neighborhood Yield Street            0.0            0.0
# 3     S            N  Neighborhood Yield Street            9.0            0.0
# 4     S            N  Neighborhood Yield Street            0.0            0.0
#
#    TRANCLASS             TRANDESCRIPT  SLOPE_PCT PVMTCATEGORY PARKBOULEVARD  \
# 0          1  PRINCIPAL TRANSIT ROUTE        4.0          ART             N
# 1          1  PRINCIPAL TRANSIT ROUTE        5.0          ART             N
# 2          0           NOT DESIGNATED       17.0      NON-ART             N
# 3          0           NOT DESIGNATED        3.0      NON-ART             N
# 4          0           NOT DESIGNATED        5.0      NON-ART             N
#
#    SHAPE_Length
# 0    305.966050
# 1    426.031562
# 2    297.147592
# 3    174.804983
# 4     73.110708

# %%
collisions.head()
# Out:
#             X          Y  OBJECTID  INCKEY  COLDETKEY REPORTNO     STATUS  \
# 0 -122.362907  47.558372         1  326120     327620  3824232  Unmatched
# 1 -122.301868  47.618931         2   65200      65200  2621299    Matched
# 2 -122.391508  47.669461         3   20100      20100  1473746    Matched
# 3 -122.346296  47.620903         4   49300      49300  2072241    Matched
# 4 -122.288688  47.532714         5   29800      29800  1177964  Unmatched
#
#        ADDRTYPE   INTKEY                                           LOCATION  \
# 0         Block      NaN  DELRIDGE WAY SW BETWEEN SW EDMUNDS ST AND SW H...
# 1         Block      NaN          E DENNY WAY BETWEEN 23RD AVE AND 24TH AVE
# 2         Block      NaN     NW 56TH ST BETWEEN 26TH AVE NW AND 28TH AVE NW
# 3  Intersection  28927.0                         TAYLOR AVE N AND THOMAS ST
# 4         Block      NaN  BEACON ER AVE S BETWEEN S PORTLAND ST AND S CH...
#
#   EXCEPTRSNCODE EXCEPTRSNDESC SEVERITYCODE                    SEVERITYDESC  \
# 0                         NaN            1  Property Damage Only Collision
# 1           NaN           NaN            1  Property Damage Only Collision
# 2           NaN           NaN            1  Property Damage Only Collision
# 3           NaN           NaN            2                Injury Collision
# 4           NaN           NaN            0                         Unknown
#
#   COLLISIONTYPE  PERSONCOUNT  PEDCOUNT  PEDCYLCOUNT  VEHCOUNT  INJURIES  \
# 0           NaN            1         0            0         0         0
# 1    Parked Car            2         0            0         2         0
# 2    Parked Car            2         0            0         2         0
# 3        Angles            4         0            0         2         3
# 4           NaN            0         0            0         0         0
#
#    SERIOUSINJURIES  FATALITIES                 INCDATE                INCDTTM  \
# 0                0           0  2019/11/16 00:00:00+00             11/16/2019
# 1                0           0  2007/01/15 00:00:00+00   1/15/2007 4:25:00 PM
# 2                0           0  2004/03/20 00:00:00+00  3/20/2004 10:25:00 PM
# 3                0           0  2006/06/03 00:00:00+00               6/3/2006
# 4                0           0  2004/11/10 00:00:00+00             11/10/2004
#
#                               JUNCTIONTYPE  SDOT_COLCODE  \
# 0  Mid-Block (not related to intersection)          16.0
# 1  Mid-Block (not related to intersection)          12.0
# 2                        Driveway Junction          11.0
# 3   At Intersection (intersection related)          11.0
# 4  Mid-Block (not related to intersection)          11.0
#
#                                         SDOT_COLDESC INATTENTIONIND UNDERINFL  \
# 0  MOTOR VEHICLE STRUCK MOTOR VEHICLE, LEFT SIDE ...            NaN       NaN
# 1  MOTOR VEHICLE STRUCK MOTOR VEHICLE, RIGHT SIDE...            NaN         0
# 2  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN         0
# 3  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN         0
# 4  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN       NaN
#
#   WEATHER ROADCOND                LIGHTCOND PEDROWNOTGRNT  SDOTCOLNUM  \
# 0     NaN      NaN                      NaN           NaN         NaN
# 1   Clear      Ice                     Dusk           NaN   7015014.0
# 2   Clear      Dry  Dark - Street Lights On           NaN   4080013.0
# 3   Clear      Dry                 Daylight           NaN   6154013.0
# 4     NaN      NaN                      NaN           NaN   4315006.0
#
#   SPEEDING ST_COLCODE              ST_COLDESC  SEGLANEKEY  CROSSWALKKEY  \
# 0      NaN                                NaN           0             0
# 1      NaN         32  One parked--one moving           0             0
# 2      NaN         32  One parked--one moving           0             0
# 3      NaN         10       Entering at angle           0             0
# 4      NaN        NaN                     NaN           0             0
#
#   HITPARKEDCAR
# 0            N
# 1            N
# 2            N
# 3            N
# 4            N

# %%
seattle_streets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23806 entries, 0 to 23805
# Data columns (total 38 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   OBJECTID       23806 non-null  int64
#  1   ARTCLASS       23800 non-null  float64
#  2   COMPKEY        23806 non-null  int64
#  3   UNITID         23800 non-null  float64
#  4   UNITID2        23800 non-null  float64
#  5   UNITIDSORT     23800 non-null  float64
#  6   UNITDESC       23800 non-null  object
#  7   STNAME_ORD     23806 non-null  object
#  8   XSTRLO         23800 non-null  object
#  9   XSTRHI         23800 non-null  object
#  10  ARTDESCRIPT    23800 non-null  object
#  11  OWNER          23800 non-null  object
#  12  STATUS         23800 non-null  object
#  13  BLOCKNBR       23800 non-null  float64
#  14  SPEEDLIMIT     23799 non-null  float64
#  15  SEGDIR         23800 non-null  object
#  16  ONEWAY         23795 non-null  object
#  17  ONEWAYDIR      23800 non-null  object
#  18  FLOW           23800 non-null  object
#  19  SEGLENGTH      23800 non-null  float64
#  20  SURFACEWIDTH   23797 non-null  float64
#  21  SURFACETYPE_1  22608 non-null  object
#  22  SURFACETYPE_2  683 non-null    object
#  23  INTRLO         23797 non-null  object
#  24  DIRLO          23800 non-null  object
#  25  INTKEYLO       23797 non-null  float64
#  26  INTRHI         23795 non-null  object
#  27  DIRHI          23799 non-null  object
#  28  NATIONHWYSYS   23800 non-null  object
#  29  STREETTYPE     23013 non-null  object
#  30  PVMTCONDINDX1  23800 non-null  float64
#  31  PVMTCONDINDX2  23800 non-null  float64
#  32  TRANCLASS      23806 non-null  int64
#  33  TRANDESCRIPT   23619 non-null  object
#  34  SLOPE_PCT      23788 non-null  float64
#  35  PVMTCATEGORY   23800 non-null  object
#  36  PARKBOULEVARD  23800 non-null  object
#  37  SHAPE_Length   23806 non-null  float64
# dtypes: float64(13), int64(3), object(22)
# memory usage: 6.9+ MB

# %%
collisions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220338 entries, 0 to 220337
# Data columns (total 40 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   X                212878 non-null  float64
#  1   Y                212878 non-null  float64
#  2   OBJECTID         220338 non-null  int64
#  3   INCKEY           220338 non-null  int64
#  4   COLDETKEY        220338 non-null  int64
#  5   REPORTNO         220338 non-null  object
#  6   STATUS           220338 non-null  object
#  7   ADDRTYPE         216632 non-null  object
#  8   INTKEY           71472 non-null   float64
#  9   LOCATION         215763 non-null  object
#  10  EXCEPTRSNCODE    99935 non-null   object
#  11  EXCEPTRSNDESC    11745 non-null   object
#  12  SEVERITYCODE     220337 non-null  object
#  13  SEVERITYDESC     220338 non-null  object
#  14  COLLISIONTYPE    194186 non-null  object
#  15  PERSONCOUNT      220338 non-null  int64
#  16  PEDCOUNT         220338 non-null  int64
#  17  PEDCYLCOUNT      220338 non-null  int64
#  18  VEHCOUNT         220338 non-null  int64
#  19  INJURIES         220338 non-null  int64
#  20  SERIOUSINJURIES  220338 non-null  int64
#  21  FATALITIES       220338 non-null  int64
#  22  INCDATE          220338 non-null  object
#  23  INCDTTM          220338 non-null  object
#  24  JUNCTIONTYPE     208404 non-null  object
#  25  SDOT_COLCODE     220337 non-null  float64
#  26  SDOT_COLDESC     220337 non-null  object
#  27  INATTENTIONIND   30187 non-null   object
#  28  UNDERINFL        194206 non-null  object
#  29  WEATHER          193998 non-null  object
#  30  ROADCOND         194078 non-null  object
#  31  LIGHTCOND        193909 non-null  object
#  32  PEDROWNOTGRNT    5177 non-null    object
#  33  SDOTCOLNUM       127205 non-null  float64
#  34  SPEEDING         9870 non-null    object
#  35  ST_COLCODE       210925 non-null  object
#  36  ST_COLDESC       194186 non-null  object
#  37  SEGLANEKEY       220338 non-null  int64
#  38  CROSSWALKKEY     220338 non-null  int64
#  39  HITPARKEDCAR     220338 non-null  object
# dtypes: float64(5), int64(12), object(23)
# memory usage: 67.2+ MB

# %%
plotPerColumnDistribution(collisions, 10, 5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-65f4fec37e5e> in <module>
# ----> 1 plotPerColumnDistribution(collisions, 10, 5)
#
# NameError: name 'plotPerColumnDistribution' is not defined
